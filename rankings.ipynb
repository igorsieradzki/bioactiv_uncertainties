# %%
from utils import load_data, highlight_max

import os
import numpy as np
import pandas as pd
from functools import partial
from collections import defaultdict

# %%
"""
Scoring Metric
"""

def top_k_precision(y_true, y_pred, k=0.10):
    
    if isinstance(k, float):
        top_k = int(k * y_true.shape[0])
    elif isinstance(k, int):
        top_k = k

    top_ids = np.argsort(y_true)[:top_k]
    top_pred = np.argsort(y_pred)[:top_k]
    
    return len(set(top_ids).intersection(set(top_pred))) / top_k

"""
Picking Strategies
"""

def normalize(x):
    return (x - x.min()) / (x - x.min()).max()

def add(y_pred, unc):
    return y_pred + unc

def add_scaled(y_pred, unc):
    return y_pred + normalize(unc)

def scale(y_pred, unc):
    return y_pred * normalize(unc)

def sum_scaled(y_pred, unc):
    return normalize(y_pred) + normalize(unc)
    
def linear_comb(y_pred, unc, lam):
    return lam * y_pred + (1 - lam) * unc

def baseline(y_pred, unc):
    return y_pred

def get_combs(lambdas=[0.5, 0.6, 0.7, 0.8, 0.9]):
    fs = []
    for lam in lambdas:
        f = partial(linear_comb, lam=lam)
        f.__name__ = f"comb_{lam}"
        fs.append(f)
        
    return fs

# %%
data_dir = './new_data'
res_dir = './data'

targets = os.listdir(data_dir)
splits = ['cv', 'bac']
split_ids = np.arange(5)

# %%
res = {}
strats = [baseline, add, scale, add_scaled, sum_scaled] + get_combs()

for target in targets:
    
    target_dict = defaultdict(list)

    for split in splits:
        for split_id in split_ids:

            _, test_dataset, sim = load_data(target, split, split_id)
            y_test = test_dataset.y.flatten()

            results_path = os.path.join(res_dir, target, split, f"large_result_{split_id}.npz")
            results = np.load(results_path)

            y_pred = results['y_pred'] 
            unc = results['unc']
            
            for strat in strats:
                y_strat = strat(y_pred, unc)
                score = top_k_precision(y_test, y_strat)
                target_dict[split + '_' + strat.__name__].append(score)
        
        for strat in strats:
            strat_name = split + '_' + strat.__name__
            
            mean = np.mean(target_dict[strat_name])
            std = np.std(target_dict[strat_name])

            target_dict[strat_name] = f"{mean:.3f} ± {std:.2f}"
        
            
    res[target] = target_dict

# %% [markdown]
# # Buying Stragies on CV
# Precision at top 10 - higher is better

# %%
col_names = ['cv_' + strat.__name__ for strat in strats]

df = pd.DataFrame.from_dict(res, orient='index')
cv_df = df[col_names]
cv_df = cv_df.rename(columns={name: name[3:] for name in col_names})
cv_df.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col3 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col0 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col6 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col7 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col9 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col0 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col9 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col0 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col6 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col7 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow4_col7 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow4_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow5_col1 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow5_col5 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow5_col6 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow5_col7 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow5_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow5_col9 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow6_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow6_col9 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow7_col0 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow8_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow8_col9 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow9_col0 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow9_col8 {
#             background-color:  yellow;
#         }    #T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow9_col9 {
#             background-color:  yellow;
#         }</style>
# <table id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >baseline</th>
#         <th class="col_heading level0 col1" >add</th>
#         <th class="col_heading level0 col2" >scale</th>
#         <th class="col_heading level0 col3" >add_scaled</th>
#         <th class="col_heading level0 col4" >sum_scaled</th>
#         <th class="col_heading level0 col5" >comb_0.5</th>
#         <th class="col_heading level0 col6" >comb_0.6</th>
#         <th class="col_heading level0 col7" >comb_0.7</th>
#         <th class="col_heading level0 col8" >comb_0.8</th>
#         <th class="col_heading level0 col9" >comb_0.9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5clevel0_row0" class="row_heading level0 row0" >CHEMBL214</th>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col0" class="data row0 col0" >0.585 ± 0.05</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col1" class="data row0 col1" >0.590 ± 0.05</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col2" class="data row0 col2" >0.518 ± 0.04</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col3" class="data row0 col3" >0.592 ± 0.06</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col4" class="data row0 col4" >0.200 ± 0.05</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col5" class="data row0 col5" >0.590 ± 0.05</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col6" class="data row0 col6" >0.590 ± 0.04</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col7" class="data row0 col7" >0.590 ± 0.04</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col8" class="data row0 col8" >0.592 ± 0.04</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow0_col9" class="data row0 col9" >0.585 ± 0.05</td>
#     </tr>    <tr>
#         <th id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5clevel0_row1" class="row_heading level0 row1" >CHEMBL216</th>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col0" class="data row1 col0" >0.743 ± 0.07</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col1" class="data row1 col1" >0.721 ± 0.07</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col2" class="data row1 col2" >0.593 ± 0.09</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col3" class="data row1 col3" >0.714 ± 0.07</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col4" class="data row1 col4" >0.129 ± 0.05</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col5" class="data row1 col5" >0.721 ± 0.07</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col6" class="data row1 col6" >0.743 ± 0.06</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col7" class="data row1 col7" >0.743 ± 0.06</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col8" class="data row1 col8" >0.743 ± 0.07</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow1_col9" class="data row1 col9" >0.743 ± 0.07</td>
#     </tr>    <tr>
#         <th id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5clevel0_row2" class="row_heading level0 row2" >CHEMBL217</th>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col0" class="data row2 col0" >0.614 ± 0.02</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col1" class="data row2 col1" >0.612 ± 0.01</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col2" class="data row2 col2" >0.070 ± 0.04</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col3" class="data row2 col3" >0.610 ± 0.01</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col4" class="data row2 col4" >0.120 ± 0.08</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col5" class="data row2 col5" >0.612 ± 0.01</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col6" class="data row2 col6" >0.612 ± 0.01</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col7" class="data row2 col7" >0.612 ± 0.01</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col8" class="data row2 col8" >0.612 ± 0.02</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow2_col9" class="data row2 col9" >0.614 ± 0.02</td>
#     </tr>    <tr>
#         <th id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5clevel0_row3" class="row_heading level0 row3" >CHEMBL224</th>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col0" class="data row3 col0" >0.663 ± 0.03</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col1" class="data row3 col1" >0.653 ± 0.04</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col2" class="data row3 col2" >0.458 ± 0.07</td>
#         <td id="T_60f37ff4_8873_11e9_a2d0_ac1f6bac1d5crow3_col3" class="data row3 col3" >0.641 ± 0.05</td>
#         <td id="T_60f37ff4_8873_11e9_a2

# %% [markdown]
# # Buying Stragies on BAC
# Precision at top 10 - higher is better

# %%
col_names = ['bac_' + strat.__name__ for strat in strats]
bac_df = df[col_names]
bac_df = bac_df.rename(columns={name: name[3:] for name in col_names})
bac_df.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col4 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col0 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col8 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col9 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col4 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col2 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col3 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow5_col7 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow6_col9 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow7_col4 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow8_col8 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow8_col9 {
#             background-color:  yellow;
#         }    #T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow9_col9 {
#             background-color:  yellow;
#         }</style>
# <table id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >_baseline</th>
#         <th class="col_heading level0 col1" >_add</th>
#         <th class="col_heading level0 col2" >_scale</th>
#         <th class="col_heading level0 col3" >_add_scaled</th>
#         <th class="col_heading level0 col4" >_sum_scaled</th>
#         <th class="col_heading level0 col5" >_comb_0.5</th>
#         <th class="col_heading level0 col6" >_comb_0.6</th>
#         <th class="col_heading level0 col7" >_comb_0.7</th>
#         <th class="col_heading level0 col8" >_comb_0.8</th>
#         <th class="col_heading level0 col9" >_comb_0.9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5clevel0_row0" class="row_heading level0 row0" >CHEMBL214</th>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col0" class="data row0 col0" >0.209 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col1" class="data row0 col1" >0.222 ± 0.09</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col2" class="data row0 col2" >0.174 ± 0.03</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col3" class="data row0 col3" >0.224 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col4" class="data row0 col4" >0.237 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col5" class="data row0 col5" >0.222 ± 0.09</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col6" class="data row0 col6" >0.219 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col7" class="data row0 col7" >0.222 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col8" class="data row0 col8" >0.219 ± 0.11</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow0_col9" class="data row0 col9" >0.211 ± 0.11</td>
#     </tr>    <tr>
#         <th id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5clevel0_row1" class="row_heading level0 row1" >CHEMBL216</th>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col0" class="data row1 col0" >0.168 ± 0.09</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col1" class="data row1 col1" >0.154 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col2" class="data row1 col2" >0.102 ± 0.07</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col3" class="data row1 col3" >0.148 ± 0.09</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col4" class="data row1 col4" >0.110 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col5" class="data row1 col5" >0.154 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col6" class="data row1 col6" >0.154 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col7" class="data row1 col7" >0.159 ± 0.10</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col8" class="data row1 col8" >0.168 ± 0.09</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow1_col9" class="data row1 col9" >0.168 ± 0.09</td>
#     </tr>    <tr>
#         <th id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5clevel0_row2" class="row_heading level0 row2" >CHEMBL217</th>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col0" class="data row2 col0" >0.202 ± 0.07</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col1" class="data row2 col1" >0.209 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col2" class="data row2 col2" >0.173 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col3" class="data row2 col3" >0.201 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col4" class="data row2 col4" >0.215 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col5" class="data row2 col5" >0.209 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col6" class="data row2 col6" >0.208 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col7" class="data row2 col7" >0.202 ± 0.08</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col8" class="data row2 col8" >0.197 ± 0.07</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow2_col9" class="data row2 col9" >0.198 ± 0.07</td>
#     </tr>    <tr>
#         <th id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5clevel0_row3" class="row_heading level0 row3" >CHEMBL224</th>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col0" class="data row3 col0" >0.250 ± 0.18</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col1" class="data row3 col1" >0.265 ± 0.19</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col2" class="data row3 col2" >0.276 ± 0.17</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col3" class="data row3 col3" >0.262 ± 0.19</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col4" class="data row3 col4" >0.232 ± 0.18</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col5" class="data row3 col5" >0.265 ± 0.19</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col6" class="data row3 col6" >0.262 ± 0.20</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col7" class="data row3 col7" >0.256 ± 0.19</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col8" class="data row3 col8" >0.256 ± 0.18</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow3_col9" class="data row3 col9" >0.256 ± 0.19</td>
#     </tr>    <tr>
#         <th id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5clevel0_row4" class="row_heading level0 row4" >CHEMBL225</th>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col0" class="data row4 col0" >0.131 ± 0.04</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col1" class="data row4 col1" >0.132 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col2" class="data row4 col2" >0.111 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col3" class="data row4 col3" >0.138 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col4" class="data row4 col4" >0.128 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col5" class="data row4 col5" >0.132 ± 0.06</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col6" class="data row4 col6" >0.129 ± 0.05</td>
#         <td id="T_60fbe798_8873_11e9_a2d0_ac1f6bac1d5crow4_col7" class="data row4 col7" >0.125 ± 0.05</td>
#         <td id="T_60fbe798_887
